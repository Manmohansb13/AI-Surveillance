# %%
import torch

print("MPS available:", torch.backends.mps.is_available())
print("MPS built:", torch.backends.mps.is_built())
# Out:
# MPS available: True
# MPS built: True

# %%
# --- CONFIGURATION CELL ---
import torch

# Device configuration
DEVICE = "mps" if torch.backends.mps.is_available() else "cpu"

# File paths
VIDEO_PATH = "crowd.mp4"
OUTPUT_PATH = "working_Crowd_oct24.mp4"

# Restricted zone (fraction of frame size)
ZONE_FRACTION_W = 1/3
ZONE_FRACTION_H = 1/3

# Frame limit
MAX_FRAMES = 100

# Suspicion thresholds
DWELL_TIME_THRESHOLD = 1.0  # seconds
MEANDER_THRESHOLD = 0.9     # below this = wandering

# %%
# --- TRACKER SETUP CELL ---
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import cv2

def setup_video(video_path, output_path):
    cap = cv2.VideoCapture(video_path)
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = int(cap.get(cv2.CAP_PROP_FPS))

    out = cv2.VideoWriter(
        output_path,
        cv2.VideoWriter_fourcc(*'mp4v'),
        fps, (width, height)
    )

    return cap, out, width, height, fps

def setup_restricted_zone(width, height):
    zone_w, zone_h = int(width * ZONE_FRACTION_W), int(height * ZONE_FRACTION_H)
    zone_x1 = width // 2 - zone_w // 2
    zone_y1 = height // 2 - zone_h // 2
    zone_x2 = zone_x1 + zone_w
    zone_y2 = zone_y1 + zone_h
    return zone_x1, zone_y1, zone_x2, zone_y2

def init_models():
    model = YOLO("yolov8n.pt")
    tracker = DeepSort(max_age=30)
    return model, tracker

# %% [markdown]
# ## Previous working but only the active getting saved

# %%
# # --- METRICS CELL ---
# import math

# # To store track data (global)
# track_data = {}

# def update_metrics(track_id, cx, cy, inside_zone, fps):
#     """Update dwell time and movement metrics per person."""
#     if track_id not in track_data:
#         track_data[track_id] = {
#             "positions": [(cx, cy)],
#             "dwell_frames": 0,
#         }
#         return

#     data = track_data[track_id]
#     data["positions"].append((cx, cy))

#     if inside_zone:
#         data["dwell_frames"] += 1
#     else:
#         data["dwell_frames"] = 0  # reset continuous dwell if leaves zone

# def compute_metrics(track_id, fps):
#     """Compute dwell time, net displacement, path length, meander ratio"""
#     data = track_data.get(track_id)
#     if not data or len(data["positions"]) < 2:
#         return 0, 0, 0, 0

#     T_dwell = data["dwell_frames"] / fps
#     (x1, y1), (x2, y2) = data["positions"][0], data["positions"][-1]
#     D_net = math.dist((x1, y1), (x2, y2))
#     L = sum(
#         math.dist(data["positions"][i], data["positions"][i+1])
#         for i in range(len(data["positions"]) - 1)
#     )
#     M = D_net / L if L > 0 else 0
#     return T_dwell, D_net, L, M

# def check_suspicious(track_id, fps, timestamp):
#     """Detect loitering/suspicious behavior"""
#     T_dwell, D_net, L, M = compute_metrics(track_id, fps)
#     suspicious = False
#     reason = None

#     if T_dwell > DWELL_TIME_THRESHOLD and M < MEANDER_THRESHOLD:
#         suspicious = True
#         reason = f"Loitering | Dwell={T_dwell:.1f}s M={M:.2f}"

#     if suspicious:
#         print(f"[{timestamp:.2f}s] Track {track_id} → {reason}")

#     return T_dwell, D_net, L, M, suspicious

# %% [markdown]
# ## New one with suspicious logs

# %%
# --- METRICS CELL ---
import math
import pandas as pd

# To store track data (global)
track_data = {}
# To store ALL suspicious detections
suspicious_log = []

# --- Thresholds ---
DWELL_TIME_THRESHOLD = 1.0  # seconds
MEANDER_THRESHOLD = 0.9    # below this => erratic or loitering

def update_metrics(track_id, cx, cy, inside_zone, fps):
    """Update dwell time and movement metrics per person."""
    if track_id not in track_data:
        track_data[track_id] = {
            "positions": [(cx, cy)],
            "dwell_frames": 0,
            "suspicious_logged": False,  # new: to avoid duplicate logging
        }
        return

    data = track_data[track_id]
    data["positions"].append((cx, cy))

    if inside_zone:
        data["dwell_frames"] += 1
    else:
        data["dwell_frames"] = 0  # reset dwell if leaves zone


def compute_metrics(track_id, fps):
    """Compute dwell time, net displacement, path length, meander ratio"""
    data = track_data.get(track_id)
    if not data or len(data["positions"]) < 2:
        return 0, 0, 0, 0

    T_dwell = data["dwell_frames"] / fps
    (x1, y1), (x2, y2) = data["positions"][0], data["positions"][-1]
    D_net = math.dist((x1, y1), (x2, y2))
    L = sum(
        math.dist(data["positions"][i], data["positions"][i + 1])
        for i in range(len(data["positions"]) - 1)
    )
    M = D_net / L if L > 0 else 0
    return T_dwell, D_net, L, M


def check_suspicious(track_id, fps, timestamp):
    """Detect loitering/suspicious behavior and log persistently"""
    global suspicious_log
    T_dwell, D_net, L, M = compute_metrics(track_id, fps)
    suspicious = False
    reason = None

    if T_dwell > DWELL_TIME_THRESHOLD and M < MEANDER_THRESHOLD:
        suspicious = True
        reason = f"Loitering | Dwell={T_dwell:.1f}s M={M:.2f}"

    if suspicious:
        data = track_data[track_id]
        if not data["suspicious_logged"]:  # only once per track
            data["suspicious_logged"] = True
            suspicious_log.append({
                "Track_ID": track_id,
                "Timestamp_s": round(timestamp, 2),
                "Dwell_Time_s": round(T_dwell, 2),
                "Net_Displacement": round(D_net, 2),
                "Path_Length": round(L, 2),
                "Meander_Ratio": round(M, 2),
                "Reason": reason,
            })
            print(f"[{timestamp:.2f}s] Track {track_id} → {reason}")

    return T_dwell, D_net, L, M, suspicious

# %%
# --- MAIN EXECUTION CELL ---
import os

os.makedirs("output", exist_ok=True)

print("Using device:", DEVICE)
model, tracker = init_models()
cap, out, width, height, fps = setup_video(VIDEO_PATH, OUTPUT_PATH)
zone_x1, zone_y1, zone_x2, zone_y2 = setup_restricted_zone(width, height)

frame_count = 0

for result in model(VIDEO_PATH, device=DEVICE, stream=True):
    frame_count += 1
    if frame_count > MAX_FRAMES:
        break

    frame = result.orig_img
    timestamp = frame_count / fps

    # Draw restricted zone
    cv2.rectangle(frame, (zone_x1, zone_y1), (zone_x2, zone_y2), (0, 0, 255), 2)
    cv2.putText(frame, "RESTRICTED", (zone_x1 + 5, zone_y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    # Extract detections
    detections = []
    for box in result.boxes:
        cls = int(box.cls[0].item())
        conf = float(box.conf[0].item())
        x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
        w, h = x2 - x1, y2 - y1
        if cls == 0 and w > 10 and h > 10:
            detections.append(([x1, y1, w, h], conf, cls))

    if not detections:
        out.write(frame)
        continue

    # Update tracker
    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        x1, y1, x2, y2 = map(int, track.to_ltrb())
        cx, cy = (x1 + x2)//2, (y1 + y2)//2
        inside_zone = zone_x1 <= cx <= zone_x2 and zone_y1 <= cy <= zone_y2

        update_metrics(track.track_id, cx, cy, inside_zone, fps)
        T_dwell, D_net, L, M, suspicious = check_suspicious(track.track_id, fps, timestamp)

        color = (0, 0, 255) if suspicious else (0, 255, 0)
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        cv2.putText(frame, f"ID {track.track_id} | {T_dwell:.1f}s", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    out.write(frame)

cap.release()
out.release()
print(f"Processing complete! Saved tracked video as {OUTPUT_PATH}")
# Out:
# Using device: mps
#
# video 1/1 (frame 1/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 2 birds, 21.8ms
# video 1/1 (frame 2/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 2 birds, 36.8ms
# video 1/1 (frame 3/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 2 birds, 16.3ms
# video 1/1 (frame 4/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 3 birds, 15.1ms
# video 1/1 (frame 5/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 2 birds, 15.1ms
# video 1/1 (frame 6/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 1 bird, 14.9ms
# video 1/1 (frame 7/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 2 birds, 15.7ms
# video 1/1 (frame 8/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 2 birds, 15.2ms
# video 1/1 (frame 9/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 2 birds, 14.9ms
# video 1/1 (frame 10/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 2 birds, 15.3ms
# video 1/1 (frame 11/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 1 bird, 15.6ms
# video 1/1 (frame 12/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 2 birds, 14.9ms
# video 1/1 (frame 13/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 2 birds, 1 dog, 16.2ms
# video 1/1 (frame 14/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 1 bird, 14.8ms
# video 1/1 (frame 15/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 2 birds, 15.4ms
# video 1/1 (frame 16/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 2 birds, 15.5ms
# video 1/1 (frame 17/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 2 birds, 16.0ms
# video 1/1 (frame 18/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 2 birds, 17.2ms
# video 1/1 (frame 19/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 1 dog, 17.1ms
# video 1/1 (frame 20/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 bird, 1 dog, 17.2ms
# video 1/1 (frame 21/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 dog, 16.0ms
# video 1/1 (frame 22/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 dog, 16.7ms
# video 1/1 (frame 23/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 bird, 1 dog, 18.2ms
# video 1/1 (frame 24/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 dog, 15.6ms
# video 1/1 (frame 25/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 dog, 16.9ms
# video 1/1 (frame 26/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 bird, 1 dog, 16.7ms
# video 1/1 (frame 27/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 22.0ms
# video 1/1 (frame 28/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 17.4ms
# video 1/1 (frame 29/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 16.0ms
# video 1/1 (frame 30/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 1 horse, 16.8ms
# video 1/1 (frame 31/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 16.8ms
# video 1/1 (frame 32/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 1 bird, 18.1ms
# video 1/1 (frame 33/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 bird, 17.8ms
# video 1/1 (frame 34/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 bird, 17.7ms
# video 1/1 (frame 35/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 1 bird, 17.1ms
# video 1/1 (frame 36/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 bird, 16.0ms
# video 1/1 (frame 37/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 bird, 17.8ms
# video 1/1 (frame 38/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 17.5ms
# video 1/1 (frame 39/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 15.6ms
# video 1/1 (frame 40/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 17.0ms
# video 1/1 (frame 41/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 2 birds, 15.2ms
# video 1/1 (frame 42/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 3 birds, 14.5ms
# video 1/1 (frame 43/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 2 birds, 16.4ms
# video 1/1 (frame 44/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 bird, 16.3ms
# video 1/1 (frame 45/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 2 birds, 19.5ms
# video 1/1 (frame 46/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 18.0ms
# [1.84s] Track 52 → Loitering | Dwell=1.0s M=0.82
# video 1/1 (frame 47/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 16.7ms
# video 1/1 (frame 48/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 bird, 15.4ms
# video 1/1 (frame 49/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 1 dog, 16.4ms
# video 1/1 (frame 50/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 1 bird, 1 dog, 16.9ms
# video 1/1 (frame 51/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 40 persons, 1 bird, 1 dog, 1 horse, 17.9ms
# video 1/1 (frame 52/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 1 bird, 1 dog, 15.9ms
# video 1/1 (frame 53/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 1 dog, 15.7ms
# video 1/1 (frame 54/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 2 birds, 1 dog, 17.0ms
# video 1/1 (frame 55/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 1 dog, 16.0ms
# video 1/1 (frame 56/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 15.3ms
# video 1/1 (frame 57/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 17.4ms
# video 1/1 (frame 58/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 1 horse, 16.2ms
# video 1/1 (frame 59/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 1 bird, 16.9ms
# video 1/1 (frame 60/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 16.3ms
# video 1/1 (frame 61/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 dog, 15.3ms
# video 1/1 (frame 62/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 1 dog, 16.3ms
# video 1/1 (frame 63/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 15.6ms
# video 1/1 (frame 64/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 1 dog, 15.3ms
# video 1/1 (frame 65/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 1 dog, 15.8ms
# video 1/1 (frame 66/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 1 dog, 15.2ms
# video 1/1 (frame 67/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 40 persons, 15.5ms
# video 1/1 (frame 68/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 1 dog, 17.7ms
# video 1/1 (frame 69/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 2 dogs, 18.4ms
# video 1/1 (frame 70/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 3 dogs, 18.4ms
# video 1/1 (frame 71/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 1 dog, 17.8ms
# video 1/1 (frame 72/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 1 bird, 17.2ms
# video 1/1 (frame 73/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 1 bird, 17.0ms
# video 1/1 (frame 74/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 41 persons, 14.7ms
# video 1/1 (frame 75/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 42 persons, 15.6ms
# video 1/1 (frame 76/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 40 persons, 1 bird, 15.4ms
# video 1/1 (frame 77/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 40 persons, 15.4ms
# video 1/1 (frame 78/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 41 persons, 15.1ms
# video 1/1 (frame 79/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 40 persons, 15.6ms
# video 1/1 (frame 80/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 40 persons, 15.2ms
# video 1/1 (frame 81/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 2 birds, 15.6ms
# video 1/1 (frame 82/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 2 birds, 18.7ms
# video 1/1 (frame 83/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 41 persons, 17.7ms
# video 1/1 (frame 84/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 1 dog, 15.2ms
# video 1/1 (frame 85/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 15.4ms
# video 1/1 (frame 86/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 1 bird, 1 dog, 16.2ms
# video 1/1 (frame 87/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 16.2ms
# video 1/1 (frame 88/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 15.1ms
# video 1/1 (frame 89/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 38 persons, 21.5ms
# video 1/1 (frame 90/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 15.5ms
# [3.60s] Track 19 → Loitering | Dwell=1.0s M=0.88
# video 1/1 (frame 91/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 1 backpack, 15.9ms
# video 1/1 (frame 92/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 39 persons, 15.4ms
# video 1/1 (frame 93/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 15.3ms
# video 1/1 (frame 94/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 backpack, 16.4ms
# video 1/1 (frame 95/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 15.2ms
# video 1/1 (frame 96/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 16.2ms
# video 1/1 (frame 97/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 17.6ms
# video 1/1 (frame 98/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 dog, 18.0ms
# video 1/1 (frame 99/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 18.1ms
# video 1/1 (frame 100/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 17.9ms
# video 1/1 (frame 101/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 15.9ms
# video 1/1 (frame 102/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 16.5ms
# video 1/1 (frame 103/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 dog, 16.1ms
# video 1/1 (frame 104/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 15.8ms
# video 1/1 (frame 105/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 36 persons, 15.5ms
# video 1/1 (frame 106/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 15.3ms
# video 1/1 (frame 107/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 17.2ms
# video 1/1 (frame 108/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 17.4ms
# video 1/1 (frame 109/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 bird, 16.1ms
# video 1/1 (frame 110/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 bird, 16.4ms
# video 1/1 (frame 111/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 bird, 1 suitcase, 16.9ms
# video 1/1 (frame 112/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 suitcase, 16.6ms
# video 1/1 (frame 113/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 dog, 17.1ms
# video 1/1 (frame 114/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 dog, 15.6ms
# video 1/1 (frame 115/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 15.5ms
# video 1/1 (frame 116/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 dog, 15.5ms
# video 1/1 (frame 117/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 15.5ms
# video 1/1 (frame 118/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 17.3ms
# video 1/1 (frame 119/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 28 persons, 1 bird, 16.1ms
# video 1/1 (frame 120/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 1 dog, 15.3ms
# video 1/1 (frame 121/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 dog, 16.0ms
# video 1/1 (frame 122/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 dog, 18.0ms
# video 1/1 (frame 123/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 1 bird, 18.4ms
# video 1/1 (frame 124/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 16.1ms
# video 1/1 (frame 125/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 16.7ms
# video 1/1 (frame 126/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 17.1ms
# video 1/1 (frame 127/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 37 persons, 1 bird, 16.6ms
# video 1/1 (frame 128/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 16.5ms
# video 1/1 (frame 129/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 15.2ms
# video 1/1 (frame 130/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 bird, 17.1ms
# [5.20s] Track 39 → Loitering | Dwell=1.0s M=0.84
# video 1/1 (frame 131/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 bird, 17.0ms
# video 1/1 (frame 132/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 bird, 16.6ms
# video 1/1 (frame 133/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 17.5ms
# video 1/1 (frame 134/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 16.6ms
# video 1/1 (frame 135/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 1 backpack, 15.4ms
# video 1/1 (frame 136/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 15.5ms
# video 1/1 (frame 137/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 backpack, 15.3ms
# video 1/1 (frame 138/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 1 suitcase, 17.5ms
# video 1/1 (frame 139/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 suitcase, 17.3ms
# video 1/1 (frame 140/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 1 suitcase, 16.2ms
# video 1/1 (frame 141/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 suitcase, 16.4ms
# video 1/1 (frame 142/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 1 suitcase, 16.4ms
# video 1/1 (frame 143/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 17.2ms
# video 1/1 (frame 144/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 15.6ms
# video 1/1 (frame 145/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 15.3ms
# video 1/1 (frame 146/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 17.2ms
# video 1/1 (frame 147/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 16.5ms
# video 1/1 (frame 148/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 15.3ms
# video 1/1 (frame 149/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 16.2ms
# video 1/1 (frame 150/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 15.3ms
# video 1/1 (frame 151/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 1 bird, 15.5ms
# video 1/1 (frame 152/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 1 bird, 15.6ms
# video 1/1 (frame 153/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 28 persons, 1 bird, 16.3ms
# video 1/1 (frame 154/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 1 bird, 16.3ms
# video 1/1 (frame 155/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 15.2ms
# video 1/1 (frame 156/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 15.2ms
# video 1/1 (frame 157/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 15.8ms
# video 1/1 (frame 158/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 28 persons, 1 bird, 15.5ms
# video 1/1 (frame 159/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 27 persons, 1 bird, 15.9ms
# video 1/1 (frame 160/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 28 persons, 1 bird, 16.4ms
# video 1/1 (frame 161/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 1 bird, 15.6ms
# video 1/1 (frame 162/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 27 persons, 1 bird, 16.6ms
# video 1/1 (frame 163/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 16.1ms
# video 1/1 (frame 164/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 15.2ms
# video 1/1 (frame 165/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 15.8ms
# video 1/1 (frame 166/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 15.9ms
# video 1/1 (frame 167/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 1 bird, 16.0ms
# video 1/1 (frame 168/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 16.0ms
# video 1/1 (frame 169/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 16.6ms
# video 1/1 (frame 170/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 17.1ms
# video 1/1 (frame 171/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 18.8ms
# video 1/1 (frame 172/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 16.1ms
# video 1/1 (frame 173/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 28 persons, 23.9ms
# [6.92s] Track 12 → Loitering | Dwell=1.0s M=0.88
# video 1/1 (frame 174/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 19.5ms
# video 1/1 (frame 175/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 16.5ms
# video 1/1 (frame 176/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 28 persons, 1 bird, 15.7ms
# video 1/1 (frame 177/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 1 bird, 16.7ms
# video 1/1 (frame 178/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 2 birds, 16.5ms
# video 1/1 (frame 179/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 17.7ms
# video 1/1 (frame 180/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 22.1ms
# video 1/1 (frame 181/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 18.3ms
# video 1/1 (frame 182/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 28 persons, 1 bird, 16.3ms
# video 1/1 (frame 183/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 26 persons, 1 bird, 1 dog, 17.2ms
# video 1/1 (frame 184/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 28 persons, 1 dog, 17.3ms
# video 1/1 (frame 185/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 27 persons, 17.1ms
# video 1/1 (frame 186/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 27 persons, 16.9ms
# video 1/1 (frame 187/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 16.9ms
# video 1/1 (frame 188/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 17.5ms
# video 1/1 (frame 189/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 16.9ms
# video 1/1 (frame 190/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 1 backpack, 19.4ms
# video 1/1 (frame 191/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 29 persons, 16.3ms
# video 1/1 (frame 192/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 17.9ms
# video 1/1 (frame 193/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 31 persons, 15.6ms
# video 1/1 (frame 194/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 skis, 17.3ms
# video 1/1 (frame 195/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 32 persons, 1 skis, 17.2ms
# video 1/1 (frame 196/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 30 persons, 17.6ms
# video 1/1 (frame 197/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 19.0ms
# video 1/1 (frame 198/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 19.8ms
# video 1/1 (frame 199/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 35 persons, 1 handbag, 17.7ms
# video 1/1 (frame 200/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 34 persons, 1 handbag, 17.6ms
# video 1/1 (frame 201/341) /Users/manmohansinghbisht/Desktop/AI Survileance/crowd.mp4: 384x640 33 persons, 2 birds, 19.7ms
# Processing complete! Saved tracked video as working_Crowd_oct24.mp4

# %%
if suspicious_log:
    df = pd.DataFrame(suspicious_log)
    df.to_csv("suspicious_activity_log.csv", index=False)
    print(f"Saved {len(df)} suspicious detections to suspicious_activity_log.csv")
else:
    print("No suspicious activity detected.")
# Out:
# Saved 4 suspicious detections to suspicious_activity_log.csv

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/manmohansinghbisht/anaconda3/envs/myenv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/manmohansinghbisht/anaconda3/envs/myenv/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/manmohansinghbisht/anaconda3/envs/myenv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/manmohansinghbisht/anaconda3/envs/myenv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/manmohansinghbisht/anaconda3/envs/myenv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/manmohansinghbisht/anaconda3/envs/myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

def export_suspicious_to_csv():
    rows = []
    for track_id, data in track_data.items():
        T_dwell, D_net, L, M = compute_metrics(track_id, fps)
        if T_dwell > DWELL_TIME_THRESHOLD and M < MEANDER_THRESHOLD:
            rows.append({
                "Track ID": track_id,
                "Dwell Time (s)": T_dwell,
                "Net Displacement": D_net,
                "Path Length": L,
                "Meander Ratio": M
            })
    if rows:
        df = pd.DataFrame(rows)
        df.to_csv("suspicious_events.csv", index=False)
        print("Saved suspicious events → suspicious_events.csv")
    else:
        print("No suspicious activity detected.")

export_suspicious_to_csv()
# Out:
# Saved suspicious events → suspicious_events.csv
